# %%
n=8
for i in range(n):
    print("*"*n)
# Out:
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********

# %%
for i in range(n):
    print("* " * i)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *

# %%
for i in range(n,0,-1):
    print("* " * i)
# Out:
# * * * * * * * *
# * * * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(n):
    print("* " * i)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *

# %%
t=6
for i in range(t):
    print(" "*i-1,)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
